# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo
#skvideo.setFFmpegPath('ffmpeg-4.1-win64-static/bin/')
import skvideo.io
import cv2
import json

from keras.models import Sequential, model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D, Reshape, BatchNormalization
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# > The function act returns the next action to do. It will often return the learned action from previous states, but sometimes, with a probability epsilon, it will return a random action. It will allow the agent to randomly explore the states.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=101 # set small when debugging
epochs_test=31 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# > The array ```position``` implements the position of the mouse, and the ```board``` represents the environement, with $+.5$ or $-1$ to implement the position of food and poison

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(4)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will end
        game_over = False

        win = 0
        lose = 0
    
        while not game_over:
            # The agent performs an action
            action = agent.act(state)
    
            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose - reward
                
            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)
       
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 10.5/9.0. Average score (1.5)
# Win/lose count 13.0/13.0. Average score (0.75)
# Win/lose count 7.0/17.0. Average score (-2.8333333333333335)
# Win/lose count 11.0/24.0. Average score (-5.375)
# Win/lose count 6.0/11.0. Average score (-5.3)
# Win/lose count 7.5/9.0. Average score (-4.666666666666667)
# Win/lose count 10.0/10.0. Average score (-4.0)
# Win/lose count 2.5/6.0. Average score (-3.9375)
# Win/lose count 14.0/10.0. Average score (-3.0555555555555554)
# Win/lose count 11.0/18.0. Average score (-3.45)
# Win/lose count 11.0/16.0. Average score (-3.590909090909091)
# Win/lose count 13.5/13.0. Average score (-3.25)
# Win/lose count 8.5/13.0. Average score (-3.3461538461538463)
# Win/lose count 4.5/5.0. Average score (-3.142857142857143)
# Win/lose count 8.0/12.0. Average score (-3.2)
# Win/lose count 10.0/13.0. Average score (-3.1875)
# Win/lose count 12.0/12.0. Average score (-3.0)
# Win/lose count 12.5/16.0. Average score (-3.0277777777777777)
# Win/lose count 10.0/14.0. Average score (-3.0789473684210527)
# Win/lose count 10.5/12.0. Average score (-3.0)
# Win/lose count 7.0/11.0. Average score (-3.0476190476190474)
# Win/lose count 7.0/14.0. Average score (-3.227272727272727)
# Win/lose count 14.0/18.0. Average score (-3.260869565217391)
# Win/lose count 11.0/15.0. Average score (-3.2916666666666665)
# Win/lose count 9.5/21.0. Average score (-3.62)
# Win/lose count 7.0/14.0. Average score (-3.75)
# Win/lose count 9.5/8.0. Average score (-3.5555555555555554)
# Win/lose count 10.0/11.0. Average score (-3.4642857142857144)
# Win/lose count 10.5/11.0. Average score (-3.3620689655172415)
# Win/lose count 8.5/18.0. Average score (-3.566666666666667)
# Win/lose count 9.0/14.0. Average score (-3.6129032258064515)
# Final score: -3.6129032258064515
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# > By definition : $Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t=0}^\infty\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]$
# $\Rightarrow Q^\pi(s,a)=E_{p^{\pi}}[r(s, a) + \gamma \sum_{t=1}^\infty\gamma^{t-1}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]$
# Taking time $t = 1$ as reference implies following $p^\pi(.|s, a)$, changieng the variable implies :
# \begin{equation}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation}
# We want to maximize $Q^\pi(s,a)$ with respect to $\pi$. As $a'$ is the only variable which depends on $\pi$, we can maximize with respect to $a'$. Thus :
# \begin{equation}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')]
# \end{equation}
# To find the optimal Q-function, we will try to minimize the distance between our Q-function and the optimal Q-function we've found above.
# \begin{equation}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation}

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        self.memory = self.memory[1-self.max_memory:] + [m]
        
    def random_access(self):
        return self.memory[np.random.randint(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16, n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(np.expand_dims(s, 0))[0])

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5, 5, self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            s, n_s, a, r, game_over = self.memory.random_access()
            input_states[i] = s.copy()
            target = self.model.predict(np.expand_dims(s, 0))[0]
            if game_over:
                ######## FILL IN
                target[a] = r
                #target_q[i, a] = r.copy()
            else:
                ######## FILL IN
                target[a] = r + self.discount * max(self.model.predict(np.expand_dims(n_s, 0))[0])
                #target_q[i, a] = (r + self.discount * max(self.model.predict(np.expand_dims(n_s, 0))[0])).copy()
            target_q[i, :] = target.copy()
            
        ######## FILL IN
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)
        l = self.model.train_on_batch(input_states, target_q)
        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model
        
            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        ####### FILL IN
        model = Sequential()
        model.add(Reshape((5*5*2, ), input_shape = (5, 5, 2)))
        model.add(Dense(16, activation = "relu"))
        model.add(Dense(4, activation = "linear"))
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train100.mp4'))
# Out:
# Epoch 000/101 | Loss 0.0175 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 001/101 | Loss 0.0071 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 002/101 | Loss 0.0085 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 003/101 | Loss 0.0116 | Win/lose count 4.0/6.0 (-2.0)
# Epoch 004/101 | Loss 0.0115 | Win/lose count 4.0/10.0 (-6.0)
# Epoch 005/101 | Loss 0.0211 | Win/lose count 3.5/3.0 (0.5)
# Epoch 006/101 | Loss 0.0074 | Win/lose count 4.0/4.0 (0.0)
# Epoch 007/101 | Loss 0.0057 | Win/lose count 3.0/3.0 (0.0)
# Epoch 008/101 | Loss 0.0204 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 009/101 | Loss 0.0144 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 010/101 | Loss 0.0099 | Win/lose count 3.5/2.0 (1.5)
# Epoch 011/101 | Loss 0.0049 | Win/lose count 4.0/1.0 (3.0)
# Epoch 012/101 | Loss 0.0074 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 013/101 | Loss 0.0151 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 014/101 | Loss 0.0198 | Win/lose count 7.5/4.0 (3.5)
# Epoch 015/101 | Loss 0.0091 | Win/lose count 8.0/5.0 (3.0)
# Epoch 016/101 | Loss 0.0340 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 017/101 | Loss 0.0037 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 018/101 | Loss 0.0038 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 019/101 | Loss 0.0187 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 020/101 | Loss 0.0058 | Win/lose count 3.5/2.0 (1.5)
# Epoch 021/101 | Loss 0.0073 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 022/101 | Loss 0.0068 | Win/lose count 3.0/3.0 (0.0)
# Epoch 023/101 | Loss 0.0026 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 024/101 | Loss 0.0137 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 025/101 | Loss 0.0325 | Win/lose count 4.0/2.0 (2.0)
# Epoch 026/101 | Loss 0.0078 | Win/lose count 6.0/3.0 (3.0)
# Epoch 027/101 | Loss 0.0115 | Win/lose count 5.0/1.0 (4.0)
# Epoch 028/101 | Loss 0.0084 | Win/lose count 4.0/2.0 (2.0)
# Epoch 029/101 | Loss 0.0077 | Win/lose count 8.0/3.0 (5.0)
# Epoch 030/101 | Loss 0.0039 | Win/lose count 5.0/2.0 (3.0)
# Epoch 031/101 | Loss 0.0297 | Win/lose count 5.0/2.0 (3.0)
# Epoch 032/101 | Loss 0.0071 | Win/lose count 3.5/2.0 (1.5)
# Epoch 033/101 | Loss 0.0034 | Win/lose count 7.0/1.0 (6.0)
# Epoch 034/101 | Loss 0.0027 | Win/lose count 5.5/1.0 (4.5)
# Epoch 035/101 | Loss 0.0075 | Win/lose count 3.5/3.0 (0.5)
# Epoch 036/101 | Loss 0.0031 | Win/lose count 6.0/3.0 (3.0)
# Epoch 037/101 | Loss 0.0025 | Win/lose count 3.5/3.0 (0.5)
# Epoch 038/101 | Loss 0.0068 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 039/101 | Loss 0.0054 | Win/lose count 3.0/3.0 (0.0)
# Epoch 040/101 | Loss 0.0075 | Win/lose count 6.5/3.0 (3.5)
# Epoch 041/101 | Loss 0.0028 | Win/lose count 6.0/0 (6.0)
# Epoch 042/101 | Loss 0.0044 | Win/lose count 1.0/1.0 (0.0)
# Epoch 043/101 | Loss 0.0041 | Win/lose count 10.0/1.0 (9.0)
# Epoch 044/101 | Loss 0.0044 | Win/lose count 4.5/1.0 (3.5)
# Epoch 045/101 | Loss 0.0063 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 046/101 | Loss 0.0090 | Win/lose count 5.5/0 (5.5)
# Epoch 047/101 | Loss 0.0055 | Win/lose count 13.0/5.0 (8.0)
# Epoch 048/101 | Loss 0.0036 | Win/lose count 4.5/2.0 (2.5)
# Epoch 049/101 | Loss 0.0043 | Win/lose count 3.5/1.0 (2.5)
# Epoch 050/101 | Loss 0.0458 | Win/lose count 6.0/4.0 (2.0)
# Epoch 051/101 | Loss 0.0027 | Win/lose count 3.0/2.0 (1.0)
# Epoch 052/101 | Loss 0.0022 | Win/lose count 7.0/2.0 (5.0)
# Epoch 053/101 | Loss 0.0045 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 054/101 | Loss 0.0019 | Win/lose count 8.5/5.0 (3.5)
# Epoch 055/101 | Loss 0.0079 | Win/lose count 1.5/1.0 (0.5)
# Epoch 056/101 | Loss 0.0015 | Win/lose count 7.0/5.0 (2.0)
# Epoch 057/101 | Loss 0.0026 | Win/lose count 10.0/5.0 (5.0)
# Epoch 058/101 | Loss 0.0940 | Win/lose count 8.0/2.0 (6.0)
# Epoch 059/101 | Loss 0.0047 | Win/lose count 9.0/2.0 (7.0)
# Epoch 060/101 | Loss 0.0033 | Win/lose count 4.5/1.0 (3.5)
# Epoch 061/101 | Loss 0.0026 | Win/lose count 8.5/2.0 (6.5)
# Epoch 062/101 | Loss 0.0033 | Win/lose count 4.5/2.0 (2.5)
# Epoch 063/101 | Loss 0.0043 | Win/lose count 5.0/4.0 (1.0)
# Epoch 064/101 | Loss 0.0470 | Win/lose count 4.5/2.0 (2.5)
# Epoch 065/101 | Loss 0.0622 | Win/lose count 5.0/2.0 (3.0)
# Epoch 066/101 | Loss 0.0056 | Win/lose count 7.5/3.0 (4.5)
# Epoch 067/101 | Loss 0.0597 | Win/lose count 2.5/2.0 (0.5)
# Epoch 068/101 | Loss 0.0038 | Win/lose count 6.5/5.0 (1.5)
# Epoch 069/101 | Loss 0.0529 | Win/lose count 4.0/3.0 (1.0)
# Epoch 070/101 | Loss 0.0513 | Win/lose count 7.5/3.0 (4.5)
# Epoch 071/101 | Loss 0.0057 | Win/lose count 8.0/3.0 (5.0)
# Epoch 072/101 | Loss 0.0032 | Win/lose count 6.5/2.0 (4.5)
# Epoch 073/101 | Loss 0.0115 | Win/lose count 6.5/2.0 (4.5)
# Epoch 074/101 | Loss 0.0027 | Win/lose count 3.0/1.0 (2.0)
# Epoch 075/101 | Loss 0.0061 | Win/lose count 17.0/0 (17.0)
# Epoch 076/101 | Loss 0.0066 | Win/lose count 6.0/2.0 (4.0)
# Epoch 077/101 | Loss 0.0498 | Win/lose count 10.0/2.0 (8.0)
# Epoch 078/101 | Loss 0.0927 | Win/lose count 12.0/5.0 (7.0)
# Epoch 079/101 | Loss 0.0044 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 080/101 | Loss 0.0042 | Win/lose count 14.0/7.0 (7.0)
# Epoch 081/101 | Loss 0.0039 | Win/lose count 6.5/2.0 (4.5)
# Epoch 082/101 | Loss 0.0032 | Win/lose count 15.0/7.0 (8.0)
# Epoch 083/101 | Loss 0.0055 | Win/lose count 8.5/0 (8.5)
# Epoch 084/101 | Loss 0.0059 | Win/lose count 15.0/5.0 (10.0)
# Epoch 085/101 | Loss 0.0030 | Win/lose count 9.5/1.0 (8.5)
# Epoch 086/101 | Loss 0.0034 | Win/lose count 5.0/0 (5.0)
# Epoch 087/101 | Loss 0.0035 | Win/lose count 5.0/2.0 (3.0)
# Epoch 088/101 | Loss 0.0031 | Win/lose count 4.5/1.0 (3.5)
# Epoch 089/101 | Loss 0.0030 | Win/lose count 3.5/1.0 (2.5)
# Epoch 090/101 | Loss 0.0589 | Win/lose count 7.5/5.0 (2.5)
# Epoch 091/101 | Loss 0.0027 | Win/lose count 5.0/1.0 (4.0)
# Epoch 092/101 | Loss 0.0037 | Win/lose count 8.0/1.0 (7.0)
# Epoch 093/101 | Loss 0.0040 | Win/lose count 11.0/6.0 (5.0)
# Epoch 094/101 | Loss 0.0551 | Win/lose count 14.0/3.0 (11.0)
# Epoch 095/101 | Loss 0.0500 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 096/101 | Loss 0.0025 | Win/lose count 6.0/1.0 (5.0)
# Epoch 097/101 | Loss 0.0038 | Win/lose count 4.0/2.0 (2.0)
# Epoch 098/101 | Loss 0.0032 | Win/lose count 4.0/3.0 (1.0)
# Epoch 099/101 | Loss 0.0080 | Win/lose count 5.0/2.0 (3.0)
# Epoch 100/101 | Loss 0.0033 | Win/lose count 8.0/1.0 (7.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
from keras.layers import Flatten

class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        ###### FILL IN
        model = Sequential()
        model.add(Conv2D(16, (3, 3), input_shape = (5, 5, self.n_state), activation = 'relu'))
        model.add(Conv2D(8, (3, 3), activation = 'relu'))
        model.add(Flatten())
        model.add(Dense(16, activation = "relu"))
        model.add(Dense(4, activation = "linear"))
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train100.mp4'))
# Out:
# Epoch 000/101 | Loss 0.0052 | Win/lose count 4.0/0 (4.0)
# Epoch 001/101 | Loss 0.0061 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 002/101 | Loss 0.0133 | Win/lose count 3.5/1.0 (2.5)
# Epoch 003/101 | Loss 0.0067 | Win/lose count 4.0/4.0 (0.0)
# Epoch 004/101 | Loss 0.0089 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 005/101 | Loss 0.0031 | Win/lose count 2.0/2.0 (0.0)
# Epoch 006/101 | Loss 0.0056 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 007/101 | Loss 0.0034 | Win/lose count 6.0/1.0 (5.0)
# Epoch 008/101 | Loss 0.0039 | Win/lose count 5.0/2.0 (3.0)
# Epoch 009/101 | Loss 0.0017 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 010/101 | Loss 0.0018 | Win/lose count 6.0/5.0 (1.0)
# Epoch 011/101 | Loss 0.0054 | Win/lose count 9.5/2.0 (7.5)
# Epoch 012/101 | Loss 0.0024 | Win/lose count 4.0/1.0 (3.0)
# Epoch 013/101 | Loss 0.0521 | Win/lose count 6.5/8.0 (-1.5)
# Epoch 014/101 | Loss 0.0617 | Win/lose count 13.5/3.0 (10.5)
# Epoch 015/101 | Loss 0.0533 | Win/lose count 8.0/2.0 (6.0)
# Epoch 016/101 | Loss 0.0022 | Win/lose count 1.0/1.0 (0.0)
# Epoch 017/101 | Loss 0.0054 | Win/lose count 6.0/3.0 (3.0)
# Epoch 018/101 | Loss 0.0028 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 019/101 | Loss 0.0026 | Win/lose count 6.0/5.0 (1.0)
# Epoch 020/101 | Loss 0.0072 | Win/lose count 3.5/1.0 (2.5)
# Epoch 021/101 | Loss 0.0398 | Win/lose count 9.0/1.0 (8.0)
# Epoch 022/101 | Loss 0.0023 | Win/lose count 8.0/1.0 (7.0)
# Epoch 023/101 | Loss 0.0040 | Win/lose count 8.5/4.0 (4.5)
# Epoch 024/101 | Loss 0.0040 | Win/lose count 5.5/1.0 (4.5)
# Epoch 025/101 | Loss 0.0033 | Win/lose count 12.0/6.0 (6.0)
# Epoch 026/101 | Loss 0.0033 | Win/lose count 8.5/3.0 (5.5)
# Epoch 027/101 | Loss 0.0026 | Win/lose count 11.5/3.0 (8.5)
# Epoch 028/101 | Loss 0.0438 | Win/lose count 4.5/1.0 (3.5)
# Epoch 029/101 | Loss 0.0059 | Win/lose count 10.5/2.0 (8.5)
# Epoch 030/101 | Loss 0.0025 | Win/lose count 7.5/1.0 (6.5)
# Epoch 031/101 | Loss 0.0030 | Win/lose count 8.5/4.0 (4.5)
# Epoch 032/101 | Loss 0.0031 | Win/lose count 4.0/3.0 (1.0)
# Epoch 033/101 | Loss 0.0041 | Win/lose count 13.0/4.0 (9.0)
# Epoch 034/101 | Loss 0.0035 | Win/lose count 7.0/5.0 (2.0)
# Epoch 035/101 | Loss 0.0411 | Win/lose count 10.0/3.0 (7.0)
# Epoch 036/101 | Loss 0.0035 | Win/lose count 13.0/5.0 (8.0)
# Epoch 037/101 | Loss 0.0069 | Win/lose count 9.0/6.0 (3.0)
# Epoch 038/101 | Loss 0.0035 | Win/lose count 7.0/1.0 (6.0)
# Epoch 039/101 | Loss 0.0035 | Win/lose count 5.0/2.0 (3.0)
# Epoch 040/101 | Loss 0.0028 | Win/lose count 16.0/2.0 (14.0)
# Epoch 041/101 | Loss 0.0019 | Win/lose count 11.0/3.0 (8.0)
# Epoch 042/101 | Loss 0.0501 | Win/lose count 21.0/3.0 (18.0)
# Epoch 043/101 | Loss 0.0337 | Win/lose count 10.0/2.0 (8.0)
# Epoch 044/101 | Loss 0.0041 | Win/lose count 4.0/0 (4.0)
# Epoch 045/101 | Loss 0.0030 | Win/lose count 11.5/1.0 (10.5)
# Epoch 046/101 | Loss 0.0304 | Win/lose count 18.5/6.0 (12.5)
# Epoch 047/101 | Loss 0.0040 | Win/lose count 16.5/4.0 (12.5)
# Epoch 048/101 | Loss 0.0041 | Win/lose count 11.5/5.0 (6.5)
# Epoch 049/101 | Loss 0.0334 | Win/lose count 11.5/2.0 (9.5)
# Epoch 050/101 | Loss 0.0045 | Win/lose count 18.5/9.0 (9.5)
# Epoch 051/101 | Loss 0.0028 | Win/lose count 11.0/4.0 (7.0)
# Epoch 052/101 | Loss 0.0025 | Win/lose count 20.0/2.0 (18.0)
# Epoch 053/101 | Loss 0.0036 | Win/lose count 16.0/3.0 (13.0)
# Epoch 054/101 | Loss 0.0023 | Win/lose count 11.0/2.0 (9.0)
# Epoch 055/101 | Loss 0.0038 | Win/lose count 20.0/2.0 (18.0)
# Epoch 056/101 | Loss 0.0037 | Win/lose count 8.0/2.0 (6.0)
# Epoch 057/101 | Loss 0.0031 | Win/lose count 11.0/3.0 (8.0)
# Epoch 058/101 | Loss 0.0473 | Win/lose count 3.0/2.0 (1.0)
# Epoch 059/101 | Loss 0.0441 | Win/lose count 7.0/0 (7.0)
# Epoch 060/101 | Loss 0.0035 | Win/lose count 9.0/2.0 (7.0)
# Epoch 061/101 | Loss 0.0033 | Win/lose count 22.0/1.0 (21.0)
# Epoch 062/101 | Loss 0.0048 | Win/lose count 5.0/2.0 (3.0)
# Epoch 063/101 | Loss 0.0057 | Win/lose count 17.0/3.0 (14.0)
# Epoch 064/101 | Loss 0.0024 | Win/lose count 6.0/1.0 (5.0)
# Epoch 065/101 | Loss 0.0017 | Win/lose count 19.5/3.0 (16.5)
# Epoch 066/101 | Loss 0.0027 | Win/lose count 10.0/2.0 (8.0)
# Epoch 067/101 | Loss 0.0046 | Win/lose count 17.0/3.0 (14.0)
# Epoch 068/101 | Loss 0.0016 | Win/lose count 15.0/4.0 (11.0)
# Epoch 069/101 | Loss 0.0011 | Win/lose count 18.5/1.0 (17.5)
# Epoch 070/101 | Loss 0.0018 | Win/lose count 15.0/4.0 (11.0)
# Epoch 071/101 | Loss 0.0041 | Win/lose count 4.5/0 (4.5)
# Epoch 072/101 | Loss 0.0483 | Win/lose count 17.5/1.0 (16.5)
# Epoch 073/101 | Loss 0.0526 | Win/lose count 24.0/8.0 (16.0)
# Epoch 074/101 | Loss 0.0079 | Win/lose count 8.0/0 (8.0)
# Epoch 075/101 | Loss 0.0612 | Win/lose count 18.5/5.0 (13.5)
# Epoch 076/101 | Loss 0.0032 | Win/lose count 9.5/2.0 (7.5)
# Epoch 077/101 | Loss 0.0016 | Win/lose count 11.5/1.0 (10.5)
# Epoch 078/101 | Loss 0.0024 | Win/lose count 7.0/2.0 (5.0)
# Epoch 079/101 | Loss 0.0033 | Win/lose count 12.0/4.0 (8.0)
# Epoch 080/101 | Loss 0.0035 | Win/lose count 19.0/2.0 (17.0)
# Epoch 081/101 | Loss 0.0044 | Win/lose count 17.0/1.0 (16.0)
# Epoch 082/101 | Loss 0.0023 | Win/lose count 10.5/2.0 (8.5)
# Epoch 083/101 | Loss 0.0511 | Win/lose count 15.5/2.0 (13.5)
# Epoch 084/101 | Loss 0.0542 | Win/lose count 13.5/6.0 (7.5)
# Epoch 085/101 | Loss 0.0030 | Win/lose count 15.5/1.0 (14.5)
# Epoch 086/101 | Loss 0.0028 | Win/lose count 6.5/6.0 (0.5)
# Epoch 087/101 | Loss 0.0027 | Win/lose count 11.5/3.0 (8.5)
# Epoch 088/101 | Loss 0.0034 | Win/lose count 5.0/3.0 (2.0)
# Epoch 089/101 | Loss 0.0055 | Win/lose count 8.0/5.0 (3.0)
# Epoch 090/101 | Loss 0.0042 | Win/lose count 12.5/2.0 (10.5)
# Epoch 091/101 | Loss 0.0019 | Win/lose count 18.5/3.0 (15.5)
# Epoch 092/101 | Loss 0.0531 | Win/lose count 9.0/6.0 (3.0)
# Epoch 093/101 | Loss 0.0040 | Win/lose count 11.5/0 (11.5)
# Epoch 094/101 | Loss 0.0559 | Win/lose count 12.5/1.0 (11.5)
# Epoch 095/101 | Loss 0.0041 | Win/lose count 10.5/1.0 (9.5)
# Epoch 096/101 | Loss 0.0033 | Win/lose count 12.0/1.0 (11.0)
# Epoch 097/101 | Loss 0.0017 | Win/lose count 20.0/4.0 (16.0)
# Epoch 098/101 | Loss 0.0037 | Win/lose count 20.5/5.0 (15.5)
# Epoch 099/101 | Loss 0.0582 | Win/lose count 6.5/3.0 (3.5)
# Epoch 100/101 | Loss 0.0118 | Win/lose count 14.5/3.0 (11.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_fc.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 10.5/1.0. Average score (9.5)
# Win/lose count 12.0/1.0. Average score (10.25)
# Win/lose count 9.5/2.0. Average score (9.333333333333334)
# Win/lose count 15.5/3.0. Average score (10.125)
# Win/lose count 7.0/0. Average score (9.5)
# Win/lose count 20.5/0. Average score (11.333333333333334)
# Win/lose count 10.5/1.0. Average score (11.071428571428571)
# Win/lose count 1.5/6.0. Average score (9.125)
# Win/lose count 14.5/3.0. Average score (9.38888888888889)
# Win/lose count 3.5/2.0. Average score (8.6)
# Win/lose count 20.5/5.0. Average score (9.227272727272727)
# Win/lose count 21.5/1.0. Average score (10.166666666666666)
# Win/lose count 16.0/1.0. Average score (10.538461538461538)
# Win/lose count 21.5/0. Average score (11.321428571428571)
# Win/lose count 10.0/3.0. Average score (11.033333333333333)
# Win/lose count 15.5/4.0. Average score (11.0625)
# Win/lose count 11.0/1.0. Average score (11.0)
# Win/lose count 6.0/1.0. Average score (10.666666666666666)
# Win/lose count 12.0/4.0. Average score (10.526315789473685)
# Win/lose count 14.0/2.0. Average score (10.6)
# Win/lose count 10.0/2.0. Average score (10.476190476190476)
# Win/lose count 8.0/3.0. Average score (10.227272727272727)
# Win/lose count 17.0/1.0. Average score (10.478260869565217)
# Win/lose count 19.5/2.0. Average score (10.770833333333334)
# Win/lose count 7.0/1.0. Average score (10.58)
# Win/lose count 12.5/2.0. Average score (10.576923076923077)
# Win/lose count 3.5/4.0. Average score (10.166666666666666)
# Win/lose count 18.0/1.0. Average score (10.410714285714286)
# Win/lose count 15.0/2.0. Average score (10.5)
# Win/lose count 18.0/4.0. Average score (10.616666666666667)
# Win/lose count 15.5/5.0. Average score (10.612903225806452)
# Final score: 10.612903225806452
# Test of the FC
# Win/lose count 15.5/1.0. Average score (14.5)
# Win/lose count 15.0/1.0. Average score (14.25)
# Win/lose count 4.0/1.0. Average score (10.5)
# Win/lose count 9.0/4.0. Average score (9.125)
# Win/lose count 7.5/2.0. Average score (8.4)
# Win/lose count 2.5/1.0. Average score (7.25)
# Win/lose count 3.0/2.0. Average score (6.357142857142857)
# Win/lose count 13.5/4.0. Average score (6.75)
# Win/lose count 5.5/2.0. Average score (6.388888888888889)
# Win/lose count 11.5/1.0. Average score (6.8)
# Win/lose count 4.0/2.0. Average score (6.363636363636363)
# Win/lose count 11.5/0. Average score (6.791666666666667)
# Win/lose count 8.0/1.0. Average score (6.8076923076923075)
# Win/lose count 9.5/3.0. Average score (6.785714285714286)
# Win/lose count 10.5/5.0. Average score (6.7)
# Win/lose count 10.0/0. Average score (6.90625)
# Win/lose count 6.5/1.0. Average score (6.823529411764706)
# Win/lose count 5.0/4.0. Average score (6.5)
# Win/lose count 14.0/1.0. Average score (6.842105263157895)
# Win/lose count 4.0/5.0. Average score (6.45)
# Win/lose count 14.0/2.0. Average score (6.714285714285714)
# Win/lose count 14.0/1.0. Average score (7.0)
# Win/lose count 10.0/3.0. Average score (7.0)
# Win/lose count 5.5/0. Average score (6.9375)
# Win/lose count 11.5/4.0. Average score (6.96)
# Win/lose count 6.0/1.0. Average score (6.884615384615385)
# Win/lose count 9.5/4.0. Average score (6.833333333333333)
# Win/lose count 1.5/1.0. Average score (6.607142857142857)
# Win/lose count 15.0/3.0. Average score (6.793103448275862)
# Win/lose count 8.0/1.0. Average score (6.8)
# Win/lose count 6.0/1.0. Average score (6.741935483870968)
# Final score: 6.741935483870968

# %%
HTML(display_videos('cnn_test30.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test30.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# > We observe that the algorithm has trouble exploring the map. But it seems that it uses a policy consisting of exploring already explored tiles. Thus it loops over mouvements he has already done.

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1, weight_visited = .1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature
        self.weight_visited = weight_visited

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        self.visited = np.zeros((grid_size,grid_size))
        
        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action, train = True):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')
            
        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        if train:reward -= self.weight_visited * self.visited[self.x, self.y]
        
        self.visited[self.x, self.y] = 1.
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1),
                                self.visited.reshape(self.grid_size, self.grid_size,1)), axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus
        self.visited = np.zeros((self.grid_size, self.grid_size))
        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                                self.position.reshape(self.grid_size, self.grid_size,1),
                                self.visited.reshape(self.grid_size, self.grid_size,1)), axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32, n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore100.mp4'))
# Out:
# Epoch 000/101 | Loss 0.0297 | Win/lose count 6.0/23.500000000000025 (-17.500000000000025)
# Epoch 001/101 | Loss 0.0146 | Win/lose count 9.5/25.300000000000082 (-15.800000000000082)
# Epoch 002/101 | Loss 0.0049 | Win/lose count 11.0/21.500000000000007 (-10.500000000000007)
# Epoch 003/101 | Loss 0.0031 | Win/lose count 4.5/20.400000000000027 (-15.900000000000027)
# Epoch 004/101 | Loss 0.0076 | Win/lose count 7.0/20.900000000000038 (-13.900000000000038)
# Epoch 005/101 | Loss 0.0148 | Win/lose count 6.0/20.500000000000025 (-14.500000000000025)
# Epoch 006/101 | Loss 0.0043 | Win/lose count 1.5/21.500000000000036 (-20.000000000000036)
# Epoch 007/101 | Loss 0.0161 | Win/lose count 8.5/19.399999999999995 (-10.899999999999995)
# Epoch 008/101 | Loss 0.0040 | Win/lose count 5.0/23.000000000000075 (-18.000000000000075)
# Epoch 009/101 | Loss 0.0065 | Win/lose count 6.5/21.70000000000005 (-15.200000000000049)
# Epoch 010/101 | Loss 0.0197 | Win/lose count 15.0/19.8 (-4.800000000000001)
# Epoch 011/101 | Loss 0.0091 | Win/lose count 11.5/27.300000000000022 (-15.800000000000022)
# Epoch 012/101 | Loss 0.0183 | Win/lose count 5.5/24.40000000000009 (-18.90000000000009)
# Epoch 013/101 | Loss 0.0355 | Win/lose count 14.0/16.19999999999997 (-2.199999999999971)
# Epoch 014/101 | Loss 0.0159 | Win/lose count 10.0/17.299999999999986 (-7.2999999999999865)
# Epoch 015/101 | Loss 0.0314 | Win/lose count 19.5/20.10000000000003 (-0.6000000000000298)
# Epoch 016/101 | Loss 0.0300 | Win/lose count 20.5/19.90000000000002 (0.5999999999999801)
# Epoch 017/101 | Loss 0.0267 | Win/lose count 12.5/17.59999999999999 (-5.099999999999991)
# Epoch 018/101 | Loss 0.0137 | Win/lose count 12.5/18.70000000000001 (-6.20000000000001)
# Epoch 019/101 | Loss 0.0483 | Win/lose count 20.0/20.30000000000003 (-0.30000000000002913)
# Epoch 020/101 | Loss 0.0077 | Win/lose count 12.5/18.299999999999997 (-5.799999999999997)
# Epoch 021/101 | Loss 0.0071 | Win/lose count 10.5/16.999999999999975 (-6.499999999999975)
# Epoch 022/101 | Loss 0.0462 | Win/lose count 16.5/21.10000000000005 (-4.600000000000051)
# Epoch 023/101 | Loss 0.0221 | Win/lose count 18.5/14.899999999999972 (3.600000000000028)
# Epoch 024/101 | Loss 0.0103 | Win/lose count 17.5/22.80000000000005 (-5.3000000000000504)
# Epoch 025/101 | Loss 0.0167 | Win/lose count 15.5/14.699999999999974 (0.8000000000000256)
# Epoch 026/101 | Loss 0.0103 | Win/lose count 18.0/16.599999999999973 (1.400000000000027)
# Epoch 027/101 | Loss 0.0145 | Win/lose count 21.5/14.499999999999975 (7.000000000000025)
# Epoch 028/101 | Loss 0.0092 | Win/lose count 21.5/15.39999999999997 (6.10000000000003)
# Epoch 029/101 | Loss 0.0080 | Win/lose count 15.5/14.899999999999975 (0.6000000000000245)
# Epoch 030/101 | Loss 0.0180 | Win/lose count 27.5/19.8 (7.699999999999999)
# Epoch 031/101 | Loss 0.0075 | Win/lose count 19.0/14.899999999999974 (4.100000000000026)
# Epoch 032/101 | Loss 0.0137 | Win/lose count 14.5/21.60000000000004 (-7.1000000000000405)
# Epoch 033/101 | Loss 0.0147 | Win/lose count 25.0/21.900000000000027 (3.099999999999973)
# Epoch 034/101 | Loss 0.0140 | Win/lose count 15.0/18.59999999999999 (-3.5999999999999908)
# Epoch 035/101 | Loss 0.0129 | Win/lose count 16.0/17.899999999999984 (-1.8999999999999844)
# Epoch 036/101 | Loss 0.0130 | Win/lose count 24.0/16.799999999999986 (7.2000000000000135)
# Epoch 037/101 | Loss 0.0158 | Win/lose count 12.5/19.90000000000003 (-7.4000000000000306)
# Epoch 038/101 | Loss 0.0117 | Win/lose count 15.0/16.59999999999997 (-1.5999999999999694)
# Epoch 039/101 | Loss 0.0218 | Win/lose count 16.0/17.09999999999998 (-1.09999999999998)
# Epoch 040/101 | Loss 0.0137 | Win/lose count 16.0/15.499999999999961 (0.5000000000000391)
# Epoch 041/101 | Loss 0.0145 | Win/lose count 22.5/12.399999999999975 (10.100000000000025)
# Epoch 042/101 | Loss 0.0123 | Win/lose count 16.5/14.699999999999967 (1.8000000000000327)
# Epoch 043/101 | Loss 0.0172 | Win/lose count 14.0/16.499999999999964 (-2.4999999999999645)
# Epoch 044/101 | Loss 0.0156 | Win/lose count 13.5/18.599999999999987 (-5.099999999999987)
# Epoch 045/101 | Loss 0.0201 | Win/lose count 20.0/15.399999999999975 (4.6000000000000245)
# Epoch 046/101 | Loss 0.0142 | Win/lose count 15.0/14.599999999999971 (0.4000000000000288)
# Epoch 047/101 | Loss 0.0181 | Win/lose count 21.0/14.999999999999979 (6.000000000000021)
# Epoch 048/101 | Loss 0.0132 | Win/lose count 20.0/16.999999999999986 (3.000000000000014)
# Epoch 049/101 | Loss 0.0237 | Win/lose count 17.5/13.599999999999971 (3.9000000000000288)
# Epoch 050/101 | Loss 0.0121 | Win/lose count 21.0/15.799999999999976 (5.200000000000024)
# Epoch 051/101 | Loss 0.0081 | Win/lose count 22.5/16.59999999999998 (5.90000000000002)
# Epoch 052/101 | Loss 0.0100 | Win/lose count 20.5/16.299999999999972 (4.200000000000028)
# Epoch 053/101 | Loss 0.0117 | Win/lose count 22.5/13.999999999999973 (8.500000000000027)
# Epoch 054/101 | Loss 0.0212 | Win/lose count 20.5/13.399999999999968 (7.100000000000032)
# Epoch 055/101 | Loss 0.0118 | Win/lose count 25.5/16.399999999999977 (9.100000000000023)
# Epoch 056/101 | Loss 0.0170 | Win/lose count 25.0/12.099999999999977 (12.900000000000023)
# Epoch 057/101 | Loss 0.0128 | Win/lose count 15.5/17.19999999999999 (-1.6999999999999886)
# Epoch 058/101 | Loss 0.0098 | Win/lose count 23.0/15.899999999999972 (7.100000000000028)
# Epoch 059/101 | Loss 0.0103 | Win/lose count 20.0/14.899999999999972 (5.100000000000028)
# Epoch 060/101 | Loss 0.0176 | Win/lose count 22.5/14.899999999999977 (7.600000000000023)
# Epoch 061/101 | Loss 0.0327 | Win/lose count 18.5/16.899999999999984 (1.6000000000000156)
# Epoch 062/101 | Loss 0.0135 | Win/lose count 12.0/14.099999999999966 (-2.099999999999966)
# Epoch 063/101 | Loss 0.0131 | Win/lose count 13.0/17.49999999999999 (-4.499999999999989)
# Epoch 064/101 | Loss 0.0115 | Win/lose count 21.0/13.799999999999974 (7.200000000000026)
# Epoch 065/101 | Loss 0.0092 | Win/lose count 20.5/14.699999999999967 (5.800000000000033)
# Epoch 066/101 | Loss 0.0087 | Win/lose count 24.5/12.799999999999978 (11.700000000000022)
# Epoch 067/101 | Loss 0.0317 | Win/lose count 21.5/13.499999999999975 (8.000000000000025)
# Epoch 068/101 | Loss 0.0134 | Win/lose count 15.0/18.300000000000008 (-3.300000000000008)
# Epoch 069/101 | Loss 0.0183 | Win/lose count 17.0/14.599999999999968 (2.4000000000000323)
# Epoch 070/101 | Loss 0.0212 | Win/lose count 22.0/17.099999999999987 (4.900000000000013)
# Epoch 071/101 | Loss 0.0100 | Win/lose count 18.0/14.099999999999968 (3.9000000000000323)
# Epoch 072/101 | Loss 0.0182 | Win/lose count 16.0/14.599999999999964 (1.4000000000000359)
# Epoch 073/101 | Loss 0.0287 | Win/lose count 22.0/15.799999999999972 (6.200000000000028)
# Epoch 074/101 | Loss 0.0303 | Win/lose count 23.5/14.099999999999982 (9.400000000000018)
# Epoch 075/101 | Loss 0.0268 | Win/lose count 19.5/15.199999999999976 (4.300000000000024)
# Epoch 076/101 | Loss 0.0215 | Win/lose count 23.5/14.299999999999972 (9.200000000000028)
# Epoch 077/101 | Loss 0.0112 | Win/lose count 17.5/14.199999999999976 (3.300000000000024)
# Epoch 078/101 | Loss 0.0255 | Win/lose count 14.5/14.29999999999997 (0.2000000000000295)
# Epoch 079/101 | Loss 0.0226 | Win/lose count 16.5/14.09999999999997 (2.4000000000000306)
# Epoch 080/101 | Loss 0.0083 | Win/lose count 22.0/15.99999999999997 (6.00000000000003)
# Epoch 081/101 | Loss 0.0121 | Win/lose count 20.0/16.199999999999967 (3.8000000000000327)
# Epoch 082/101 | Loss 0.0170 | Win/lose count 18.0/15.499999999999964 (2.5000000000000355)
# Epoch 083/101 | Loss 0.0386 | Win/lose count 18.5/12.099999999999984 (6.400000000000016)
# Epoch 084/101 | Loss 0.0087 | Win/lose count 22.5/13.799999999999972 (8.700000000000028)
# Epoch 085/101 | Loss 0.0247 | Win/lose count 22.0/15.99999999999997 (6.00000000000003)
# Epoch 086/101 | Loss 0.0122 | Win/lose count 20.5/17.299999999999983 (3.200000000000017)
# Epoch 087/101 | Loss 0.0100 | Win/lose count 23.0/15.799999999999974 (7.200000000000026)
# Epoch 088/101 | Loss 0.0114 | Win/lose count 21.5/13.899999999999977 (7.600000000000023)
# Epoch 089/101 | Loss 0.0197 | Win/lose count 17.0/21.80000000000004 (-4.80000000000004)
# Epoch 090/101 | Loss 0.0140 | Win/lose count 18.0/18.600000000000016 (-0.6000000000000156)
# Epoch 091/101 | Loss 0.0244 | Win/lose count 11.5/16.899999999999963 (-5.399999999999963)
# Epoch 092/101 | Loss 0.0156 | Win/lose count 16.0/16.29999999999997 (-0.29999999999996874)
# Epoch 093/101 | Loss 0.0257 | Win/lose count 17.0/13.399999999999974 (3.6000000000000263)
# Epoch 094/101 | Loss 0.0106 | Win/lose count 15.5/18.6 (-3.1000000000000014)
# Epoch 095/101 | Loss 0.0153 | Win/lose count 18.0/13.199999999999973 (4.800000000000027)
# Epoch 096/101 | Loss 0.0308 | Win/lose count 23.0/12.299999999999978 (10.700000000000022)
# Epoch 097/101 | Loss 0.0236 | Win/lose count 17.5/14.09999999999997 (3.4000000000000306)
# Epoch 098/101 | Loss 0.0156 | Win/lose count 23.5/13.899999999999974 (9.600000000000026)
# Epoch 099/101 | Loss 0.0154 | Win/lose count 17.5/14.699999999999974 (2.8000000000000256)
# Epoch 100/101 | Loss 0.0157 | Win/lose count 18.0/17.199999999999978 (0.800000000000022)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore30.mp4'))
# Out:
# Win/lose count 17.5/13.899999999999972. Average score (3.600000000000028)
# Win/lose count 13.5/15.399999999999968. Average score (0.8500000000000307)
# Win/lose count 19.5/15.89999999999997. Average score (1.7666666666666966)
# Win/lose count 10.0/13.799999999999967. Average score (0.37500000000003064)
# Win/lose count 17.0/17.399999999999995. Average score (0.22000000000002515)
# Win/lose count 19.5/16.49999999999998. Average score (0.6833333333333579)
# Win/lose count 20.5/14.699999999999976. Average score (1.4142857142857388)
# Win/lose count 16.0/17.499999999999986. Average score (1.050000000000023)
# Win/lose count 19.5/13.29999999999998. Average score (1.6222222222222449)
# Win/lose count 25.0/13.799999999999974. Average score (2.580000000000023)
# Win/lose count 23.0/15.099999999999973. Average score (3.063636363636387)
# Win/lose count 29.5/12.699999999999973. Average score (4.208333333333357)
# Win/lose count 20.5/13.599999999999975. Average score (4.41538461538464)
# Win/lose count 24.5/12.999999999999977. Average score (4.921428571428597)
# Win/lose count 15.0/16.499999999999975. Average score (4.493333333333358)
# Win/lose count 18.0/13.899999999999974. Average score (4.468750000000025)
# Win/lose count 21.5/12.599999999999971. Average score (4.729411764705908)
# Win/lose count 13.5/17.199999999999985. Average score (4.261111111111136)
# Win/lose count 16.0/19.100000000000012. Average score (3.8736842105263385)
# Win/lose count 14.5/15.599999999999968. Average score (3.6250000000000235)
# Win/lose count 17.0/15.099999999999966. Average score (3.5428571428571667)
# Win/lose count 21.0/15.09999999999997. Average score (3.6500000000000243)
# Win/lose count 19.5/14.799999999999965. Average score (3.6956521739130683)
# Win/lose count 20.0/15.69999999999997. Average score (3.720833333333358)
# Win/lose count 21.0/11.899999999999977. Average score (3.936000000000025)
# Win/lose count 25.5/14.999999999999977. Average score (4.1884615384615635)
# Win/lose count 23.0/14.59999999999997. Average score (4.34444444444447)
# Win/lose count 20.0/13.099999999999975. Average score (4.435714285714311)
# Win/lose count 27.5/14.799999999999978. Average score (4.720689655172439)
# Win/lose count 20.0/14.299999999999972. Average score (4.753333333333359)
# Win/lose count 17.0/17.399999999999984. Average score (4.587096774193574)
# Final score: 4.587096774193574
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
